# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing_df = pd.read_csv('housing.csv')

# %%
#a
# Print the shape,axes,and dtypes attributes of housing_df dataframe
print("shape = ", housing_df.shape)
print("axes = ", housing_df.axes)
print("dtype =\n", housing_df.dtypes)
# Out:
# shape =  (1460, 19)
# axes =  [RangeIndex(start=0, stop=1460, step=1), Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'Street', 'BldgType',
#        'OverallQual', 'YearBuilt', 'TotalBsmtSF', 'FullBath', 'HalfBath',
#        'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'SalePrice'],
#       dtype='object')]
# dtype =
#  Id                int64
# MSSubClass        int64
# LotFrontage     float64
# LotArea           int64
# Street           object
# BldgType         object
# OverallQual       int64
# YearBuilt         int64
# TotalBsmtSF       int64
# FullBath          int64
# HalfBath          int64
# Fireplaces        int64
# FireplaceQu      object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageCars        int64
# GarageArea        int64
# SalePrice         int64
# dtype: object

# %%
#b
#Print first 10 rows of housing_df dataframe using pandas.DataFrame.head() function.
print(housing_df.head(n = 10))
# Out:
#    Id  MSSubClass  LotFrontage  LotArea Street BldgType  OverallQual  \
# 0   1          60         65.0     8450   Pave     1Fam            7
# 1   2          20         80.0     9600   Pave     1Fam            6
# 2   3          60         68.0    11250   Pave     1Fam            7
# 3   4          70         60.0     9550   Pave     1Fam            7
# 4   5          60         84.0    14260   Pave     1Fam            8
# 5   6          50         85.0    14115   Pave     1Fam            5
# 6   7          20         75.0    10084   Pave     1Fam            8
# 7   8          60          NaN    10382   Pave     1Fam            7
# 8   9          50         51.0     6120   Pave     1Fam            7
# 9  10         190         50.0     7420   Pave   2fmCon            5
#
#    YearBuilt  TotalBsmtSF  FullBath  HalfBath  Fireplaces FireplaceQu  \
# 0       2003          856         2         1           0         NaN
# ...

# %%
#c
#How many samples does housing_df include?
print("Samples = ", housing_df.shape[0])
#There are a total of 1460 samples in the housing dataset
# Out:
# Samples =  1460

# %% [markdown]
# Part d)
# Based on your knowledge of the dataset and its stated usage, do you think we are dealing with unsupervised learning problem or a supervised learning problem? Justify your answer.

# %% [markdown]
# Part e
# How many independent variables (features,attributes, preditors,etc.) does this dataset have? List down the names of these variables.

# %% [markdown]
# Part f
# How many dependent variables (if any) does this dataset have? List down the names of these variables.

# %% [markdown]
# Part g
# How many of the variables in this dataset are categorical variables? List down the names of these variables

# %%
#h
# How many samples have a GarageArea greater than zero? For those samples,plot SalePrice as a function of GarageArea. 
#What does your plot suggest about predicting the SalePrice using GarageArea?
LotArea = housing_df[housing_df.columns[3]]
print(LotArea.shape)
SalePrice = housing_df[housing_df.columns[18]]
print(SalePrice.shape)
plt.figure(figsize=(8, 6), dpi=80)
plt.figure(1)
plt.plot(LotArea,SalePrice,'bo')
plt.figure(figsize=(8, 6), dpi=80)
plt.figure(2)
figure2 = plt.plot(LotArea,SalePrice)
# Out:
# (1460,)
# (1460,)

# %% [markdown]
# Part i
# How many samples have a GarageArea greater than zero? For those samples, plot SalePrice as a function of GarageArea. What does your plot suggest about predicting the SalePrice using GarageArea?

# %%
Garage = housing_df[['GarageArea']]
df = housing_df[['GarageArea', 'SalePrice']]
Garage = Garage.to_numpy()
df= df[df['GarageArea'] != 0]
print(df.shape)
print("Samples that have a GarageArea greater than zero =", df.shape[0])
plt.figure(figsize=(8, 6), dpi=80)
plt.figure(1)
plt.plot(df.GarageArea,df.SalePrice,'bo')
plt.figure(figsize=(8, 6), dpi=80)
plt.figure(2)
figure2 = plt.plot(df.GarageArea,df.SalePrice)
# Out:
# (1379, 2)
# Samples that have a GarageArea greater than zero = 1379
